# %%
import os
import time
import pickle
import math
import random
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import seaborn as sns
from scipy import interpolate
from datetime import datetime
import pandas as pd
from tool import EarlyStopping
from sklearn.metrics import roc_auc_score,mean_squared_error,mean_absolute_error, r2_score
from common import *
from net import CRNN

import torch
import torch.nn.functional as F
import torch.optim as optim

from torch import nn
from torch.autograd import Variable
from torch.utils.data import DataLoader, Dataset, Sampler, TensorDataset
from torch.utils.data.sampler import RandomSampler
    
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1-Data preparation

# %%
n_cyc = 30
in_stride = 3
fea_num = 100

v_low = 3.36
v_upp = 3.60
q_low = 610
q_upp = 1190
rul_factor = 3000
cap_factor = 1190

# %%
pkl_list = os.listdir('./data/our_data/')
pkl_list = sorted(pkl_list, key=lambda x:int(x.split('-')[0])*10 + int(x[-5]))

train_name = []
for name in pkl_list:
    train_name.append(name[:-4])

# %%
all_loader = dict()
print('----init_train----')
for name in train_name:
    tmp_fea, tmp_lbl = get_xy(name, n_cyc, in_stride, fea_num, v_low, v_upp, q_low, q_upp, rul_factor, cap_factor)
    all_loader.update({name:{'fea':tmp_fea,'lbl':tmp_lbl}})
# Out:
# ----init_train----
# 1-1 length is 1466 v_max: 0.9583 q_max: 0.9074 dv_max: 0.1396 dq_max: 0.0001
# 1-2 length is 2640 v_max: 0.9633 q_max: 0.9439 dv_max: 0.1342 dq_max: 0.0023
# 1-3 length is 1820 v_max: 0.9325 q_max: 0.9233 dv_max: 0.0730 dq_max: 0.0053
# 1-4 length is 1462 v_max: 0.9233 q_max: 0.9234 dv_max: 0.0802 dq_max: 0.0052
# 1-5 length is 1933 v_max: 0.9271 q_max: 0.9128 dv_max: 0.0013 dq_max: 0.0079
# 1-6 length is 1105 v_max: 0.9596 q_max: 0.9022 dv_max: 0.0755 dq_max: 0.0000
# 1-7 length is 1640 v_max: 0.9558 q_max: 0.9232 dv_max: 0.1589 dq_max: 0.0000
# 1-8 length is 2247 v_max: 0.9571 q_max: 0.9363 dv_max: 0.1714 dq_max: 0.0000
# 2-2 length is 2613 v_max: 0.9492 q_max: 0.9753 dv_max: 0.1172 dq_max: 0.0024
# 2-3 length is 1713 v_max: 0.9363 q_max: 0.9285 dv_max: 0.1237 dq_max: 0.0079
# 2-4 length is 1461 v_max: 0.9517 q_max: 0.9232 dv_max: 0.1456 dq_max: 0.0000
# 2-5 length is 1348 v_max: 0.9300 q_max: 0.9149 dv_max: 0.0301 dq_max: 0.0079
# 2-6 length is 1534 v_max: 0.9208 q_max: 0.9439 dv_max: 0.0951 dq_max: 0.0078
# 2-7 length is 2164 v_max: 0.9154 q_max: 0.9570 dv_max: 0.0613 dq_max: 0.0078
# 2-8 length is 1443 v_max: 0.9442 q_max: 0.9150 dv_max: 0.2010 dq_max: 0.0022
# 3-1 length is 1900 v_max: 0.9208 q_max: 0.9543 dv_max: 0.1275 dq_max: 0.0026
# 3-2 length is 2245 v_max: 0.9171 q_max: 0.9596 dv_max: 0.0995 dq_max: 0.0052
# 3-3 length is 1611 v_max: 0.9067 q_max: 0.9412 dv_max: 0.1014 dq_max: 0.0026
# 3-4 length is 1728 v_max: 0.9375 q_max: 0.9123 dv_max: 0.1362 dq_max: 0.0023
# 3-5 length is 2619 v_max: 0.9529 q_max: 0.9913 dv_max: 0.1550 dq_max: 0.0022
# 3-6 length is 2453 v_max: 0.9154 q_max: 0.9493 dv_max: 0.0981 dq_max: 0.0052
# 3-7 length is 2441 v_max: 0.9400 q_max: 0.9094 dv_max: 0.1498 dq_max: 0.0025
# 3-8 length is 2304 v_max: 0.9054 q_max: 0.9807 dv_max: 0.0825 dq_max: 0.0026
# 4-1 length is 2179 v_max: 0.9221 q_max: 0.9305 dv_max: 0.1360 dq_max: 0.0026
# 4-2 length is 1744 v_max: 0.9454 q_max: 0.9521 dv_max: 0.1773 dq_max: 0.0053
# 4-3 length is 1104 v_max: 0.9517 q_max: 0.9126 dv_max: 0.1777 dq_max: 0.0001
# 4-4 length is 1453 v_max: 0.9517 q_max: 0.9070 dv_max: 0.1828 dq_max: 0.0022
# 4-5 length is 1523 v_max: 0.9504 q_max: 0.9423 dv_max: 0.1695 dq_max: 0.0001
# 4-6 length is 1342 v_max: 0.9442 q_max: 0.9021 dv_max: 0.1449 dq_max: 0.0001
# 4-7 length is 2178 v_max: 0.9633 q_max: 0.9857 dv_max: 0.1623 dq_max: 0.0024
# 4-8 length is 1668 v_max: 0.9388 q_max: 0.9522 dv_max: 0.1361 dq_max: 0.0053
# 5-1 length is 2469 v_max: 0.9646 q_max: 0.9472 dv_max: 0.1316 dq_max: 0.0001
# 5-2 length is 1888 v_max: 0.9350 q_max: 0.9341 dv_max: 0.1048 dq_max: 0.0079
# 5-3 length is 2651 v_max: 0.9621 q_max: 0.9419 dv_max: 0.1226 dq_max: 0.0000
# 5-4 length is 1924 v_max: 0.9646 q_max: 0.9161 dv_max: 0.1695 dq_max: 0.0002
# 5-5 length is 1545 v_max: 0.9363 q_max: 0.9338 dv_max: 0.0678 dq_max: 0.0052
# 5-6 length is 2422 v_max: 0.9646 q_max: 0.9466 dv_max: 0.1432 dq_max: 0.0001
# 5-7 length is 1410 v_max: 0.9542 q_max: 0.9155 dv_max: 0.1575 dq_max: 0.0000
# 6-1 length is 1571 v_max: 0.9583 q_max: 0.9054 dv_max: 0.1366 dq_max: 0.0001
# 6-2 length is 1870 v_max: 0.9363 q_max: 0.9547 dv_max: 0.0852 dq_max: 0.0077
# 6-3 length is 1766 v_max: 0.9350 q_max: 0.9470 dv_max: 0.1190 dq_max: 0.0026
# 6-4 length is 1679 v_max: 0.9479 q_max: 0.9154 dv_max: 0.1634 dq_max: 0.0000
# 6-5 length is 2140 v_max: 0.9583 q_max: 0.9262 dv_max: 0.1442 dq_max: 0.0000
# 6-6 length is 2430 v_max: 0.9388 q_max: 0.9282 dv_max: 0.0448 dq_max: 0.0077
# 6-8 length is 2412 v_max: 0.9504 q_max: 0.9492 dv_max: 0.1075 dq_max: 0.0000
# 7-1 length is 1652 v_max: 0.9283 q_max: 0.9312 dv_max: 0.1840 dq_max: 0.0001
# 7-2 length is 1992 v_max: 0.8846 q_max: 0.9703 dv_max: 0.1176 dq_max: 0.0026
# 7-3 length is 1257 v_max: 0.9596 q_max: 0.9103 dv_max: 0.2290 dq_max: 0.0002
# 7-4 length is 1355 v_max: 0.9583 q_max: 0.9126 dv_max: 0.2099 dq_max: 0.0001
# 7-5 length is 1837 v_max: 0.9312 q_max: 0.9571 dv_max: 0.1703 dq_max: 0.0022
# 7-6 length is 1381 v_max: 0.9492 q_max: 0.9173 dv_max: 0.2074 dq_max: 0.0023
# 7-7 length is 1647 v_max: 0.9492 q_max: 0.9180 dv_max: 0.1932 dq_max: 0.0001
# 7-8 length is 1900 v_max: 0.9429 q_max: 0.9548 dv_max: 0.1705 dq_max: 0.0053
# 8-1 length is 1270 v_max: 0.9596 q_max: 0.9158 dv_max: 0.2056 dq_max: 0.0001
# 8-2 length is 2003 v_max: 0.9633 q_max: 0.9442 dv_max: 0.1700 dq_max: 0.0001
# 8-3 length is 2252 v_max: 0.9350 q_max: 0.9530 dv_max: 0.1125 dq_max: 0.0026
# 8-4 length is 1847 v_max: 0.9529 q_max: 0.9233 dv_max: 0.1883 dq_max: 0.0000
# 8-5 length is 1310 v_max: 0.9646 q_max: 0.9100 dv_max: 0.1955 dq_max: 0.0001
# 8-6 length is 2327 v_max: 0.9633 q_max: 0.9814 dv_max: 0.1916 dq_max: 0.0001
# 8-7 length is 2009 v_max: 0.9583 q_max: 0.9286 dv_max: 0.2171 dq_max: 0.0001
# 8-8 length is 1641 v_max: 0.9312 q_max: 0.9603 dv_max: 0.1175 dq_max: 0.0026
# 9-1 length is 2019 v_max: 0.9117 q_max: 0.9813 dv_max: 0.1303 dq_max: 0.0000
# 9-2 length is 2105 v_max: 0.9375 q_max: 0.9698 dv_max: 0.1536 dq_max: 0.0026
# 9-3 length is 1867 v_max: 0.9300 q_max: 0.9707 dv_max: 0.1738 dq_max: 0.0001
# 9-4 length is 1937 v_max: 0.9233 q_max: 0.9761 dv_max: 0.1635 dq_max: 0.0027
# 9-5 length is 2130 v_max: 0.9196 q_max: 0.9578 dv_max: 0.1308 dq_max: 0.0002
# 9-6 length is 1704 v_max: 0.9067 q_max: 0.9701 dv_max: 0.1017 dq_max: 0.0022
# 9-7 length is 1974 v_max: 0.9300 q_max: 0.9627 dv_max: 0.1583 dq_max: 0.0026
# 9-8 length is 2270 v_max: 0.9300 q_max: 0.9468 dv_max: 0.0995 dq_max: 0.0053
# 10-1 length is 1664 v_max: 0.9429 q_max: 0.9206 dv_max: 0.1914 dq_max: 0.0000
# 10-2 length is 1659 v_max: 0.8987 q_max: 0.9658 dv_max: 0.1261 dq_max: 0.0027
# 10-3 length is 1810 v_max: 0.9337 q_max: 0.9315 dv_max: 0.1795 dq_max: 0.0000
# 10-4 length is 1773 v_max: 0.9467 q_max: 0.9524 dv_max: 0.1805 dq_max: 0.0026
# 10-5 length is 1992 v_max: 0.9258 q_max: 0.9545 dv_max: 0.1255 dq_max: 0.0026
# 10-6 length is 2247 v_max: 0.9596 q_max: 0.9966 dv_max: 0.1959 dq_max: 0.0002
# 10-7 length is 1745 v_max: 0.9325 q_max: 0.9525 dv_max: 0.1280 dq_max: 0.0053
# 10-8 length is 1362 v_max: 0.9517 q_max: 0.9290 dv_max: 0.1761 dq_max: 0.0000

# %% [markdown]
# # 2-Dataloader generation

# %%
new_valid = ['4-3', '5-7', '3-3', '2-3', '9-3', '10-5', '3-2', '3-7']
new_train = ['9-1', '2-2', '4-7','9-7', '1-8','4-6','2-7','8-4', '7-2','10-3', '2-4', '7-4', '3-4',
            '5-4', '8-7','7-7', '4-4','1-3', '7-1','5-2', '6-4', '9-8','9-5','6-3','10-8','1-6','3-5',
             '2-6', '3-8', '3-6', '4-8', '7-8','5-1', '2-8', '8-2','1-5','7-3', '10-2','5-5', '9-2','5-6', '1-7', 
             '8-3', '4-1','4-2','1-4','6-5', ]
new_test  = ['9-6','4-5','1-2', '10-7','1-1', '6-1','6-6', '9-4','10-4','8-5', '5-3','10-6',
            '2-5','6-2','3-1','8-8', '8-1','8-6','7-6','6-8','7-5','10-1']

# %%
stride = 10
train_fea, train_lbl = [], []
for name in new_train + new_valid:
    tmp_fea, tmp_lbl = all_loader[name]['fea'],all_loader[name]['lbl']
    train_fea.append(tmp_fea[::stride])
    train_lbl.append(tmp_lbl[::stride])
train_fea = np.vstack(train_fea)
train_lbl = np.vstack(train_lbl).squeeze()

stride = 10
valid_fea, valid_lbl = [], []
for name in new_test:
    tmp_fea, tmp_lbl = all_loader[name]['fea'],all_loader[name]['lbl']
    valid_fea.append(tmp_fea[::stride])
    valid_lbl.append(tmp_lbl[::stride])
valid_fea = np.vstack(valid_fea)
valid_lbl = np.vstack(valid_lbl).squeeze()

print(train_fea.shape, train_lbl.shape, valid_fea.shape, valid_lbl.shape)
# Out:
# (10279, 10, 100, 4) (10279, 11) (4074, 10, 100, 4) (4074, 11)

# %%
seed_torch(0)
batch_size = 256

train_fea_ = train_fea[:].copy()
train_lbl_ = train_lbl[:].copy()

train_fea_ = train_fea_.transpose(0,3,2,1)
valid_fea_ = valid_fea.transpose(0,3,2,1)

trainset = TensorDataset(torch.Tensor(train_fea_), torch.Tensor(train_lbl_))
validset = TensorDataset(torch.Tensor(valid_fea_), torch.Tensor(valid_lbl))

train_loader = DataLoader(trainset, batch_size=batch_size,shuffle=True)
valid_loader = DataLoader(validset, batch_size=batch_size,)

train_loader_t = DataLoader(trainset, batch_size=batch_size,shuffle=False)

# %% [markdown]
# # 3-Model pre-training

# %% [markdown]
#  The pretrained model is saved in './model/wx_inner/wx_inner_pretrain_end.pt'
#
#  If loading this model, readers can skip step 3 and run step 4 directly.

# %%
'''
lamda (float): The weight of RUL loss
alpha (List: [float]): The weights of Capacity loss
'''         
lamda = 1e-2
alpha = torch.Tensor([0.1] * 10 )

# %%
'''
model training 
'''
tic = time.time()
seed_torch(0)
device = 'cuda'
model = CRNN(100,4,64,64)
model = model.to(device)

num_epochs = 10000


model_load = False
trainer = Trainer(lr = 8e-4, n_epochs = num_epochs,device = device, patience = 1200,
                  lamda = lamda, alpha = alpha, model_name='./model/wx_inner/wx_inner_pretrain')
model ,train_loss, valid_loss, total_loss = trainer.train(train_loader, valid_loader, model, model_load)

print(time.time()-tic)
# Out:
# Epoch number :  100
# -- "train" loss 0.009955 -- "valid" loss 0.01206 -- "total" loss 0.0001218
# Epoch number :  200
# -- "train" loss 0.006902 -- "valid" loss 0.00991 -- "total" loss 8.796e-05
# Epoch number :  300
# -- "train" loss 0.006617 -- "valid" loss 0.009352 -- "total" loss 7.93e-05
# Epoch number :  400
# -- "train" loss 0.006433 -- "valid" loss 0.009074 -- "total" loss 7.556e-05
# Epoch number :  500
# -- "train" loss 0.006245 -- "valid" loss 0.009054 -- "total" loss 7.239e-05
# Epoch number :  600
# -- "train" loss 0.006004 -- "valid" loss 0.008742 -- "total" loss 6.969e-05
# Epoch number :  700
# -- "train" loss 0.005746 -- "valid" loss 0.008508 -- "total" loss 6.752e-05
# Epoch number :  800
# -- "train" loss 0.005426 -- "valid" loss 0.008146 -- "total" loss 6.561e-05
# Epoch number :  900
# -- "train" loss 0.005078 -- "valid" loss 0.007796 -- "total" loss 6.365e-05
# Epoch number :  1000
# -- "train" loss 0.00468 -- "valid" loss 0.007663 -- "total" loss 6.089e-05
# Epoch number :  1100
# -- "train" loss 0.004312 -- "valid" loss 0.007416 -- "total" loss 6.268e-05
# Epoch number :  1200
# -- "train" loss 0.003777 -- "valid" loss 0.007198 -- "total" loss 5.418e-05
# Epoch number :  1300
# -- "train" loss 0.00335 -- "valid" loss 0.006785 -- "total" loss 5.098e-05
# Epoch number :  1400
# -- "train" loss 0.002927 -- "valid" loss 0.006669 -- "total" loss 4.675e-05
# Epoch number :  1500
# -- "train" loss 0.002748 -- "valid" loss 0.006527 -- "total" loss 4.487e-05
# Epoch number :  1600
# -- "train" loss 0.002303 -- "valid" loss 0.006293 -- "total" loss 4.147e-05
# Epoch number :  1700
# -- "train" loss 0.002061 -- "valid" loss 0.006189 -- "total" loss 3.964e-05
# Epoch number :  1800
# -- "train" loss 0.001797 -- "valid" loss 0.005926 -- "total" loss 3.579e-05
# Epoch number :  1900
# -- "train" loss 0.001701 -- "valid" loss 0.005726 -- "total" loss 3.412e-05
# Epoch number :  2000
# -- "train" loss 0.001656 -- "valid" loss 0.006085 -- "total" loss 3.671e-05
# Epoch number :  2100
# -- "train" loss 0.0013 -- "valid" loss 0.00574 -- "total" loss 3.059e-05
# Epoch number :  2200
# -- "train" loss 0.001153 -- "valid" loss 0.005451 -- "total" loss 2.837e-05
# Epoch number :  2300
# -- "train" loss 0.001063 -- "valid" loss 0.005793 -- "total" loss 2.633e-05
# Epoch number :  2400
# -- "train" loss 0.001031 -- "valid" loss 0.005663 -- "total" loss 2.748e-05
# Epoch number :  2500
# -- "train" loss 0.0008563 -- "valid" loss 0.005793 -- "total" loss 2.388e-05
# Epoch number :  2600
# -- "train" loss 0.0007747 -- "valid" loss 0.005472 -- "total" loss 2.231e-05
# Epoch number :  2700
# -- "train" loss 0.0007397 -- "valid" loss 0.005415 -- "total" loss 2.18e-05
# Epoch number :  2800
# -- "train" loss 0.0006311 -- "valid" loss 0.005647 -- "total" loss 2.011e-05
# Epoch number :  2900
# -- "train" loss 0.0005889 -- "valid" loss 0.005632 -- "total" loss 1.98e-05
# Epoch number :  3000
# -- "train" loss 0.0005695 -- "valid" loss 0.005542 -- "total" loss 1.89e-05
# Epoch number :  3100
# -- "train" loss 0.0005195 -- "valid" loss 0.005577 -- "total" loss 1.828e-05
# Epoch number :  3200
# -- "train" loss 0.0005421 -- "valid" loss 0.005564 -- "total" loss 1.838e-05
# Epoch number :  3300
# -- "train" loss 0.0004054 -- "valid" loss 0.00547 -- "total" loss 1.609e-05
# Epoch number :  3400
# -- "train" loss 0.0004816 -- "valid" loss 0.005219 -- "total" loss 1.714e-05
# Epoch number :  3500
# -- "train" loss 0.0003562 -- "valid" loss 0.005297 -- "total" loss 1.53e-05
# Epoch number :  3600
# -- "train" loss 0.0003242 -- "valid" loss 0.005241 -- "total" loss 1.462e-05
# Epoch number :  3700
# -- "train" loss 0.0002968 -- "valid" loss 0.005441 -- "total" loss 1.394e-05
# Epoch number :  3800
# -- "train" loss 0.000318 -- "valid" loss 0.00555 -- "total" loss 1.388e-05
# Epoch number :  3900
# -- "train" loss 0.000949 -- "valid" loss 0.005688 -- "total" loss 2.585e-05
# Epoch number :  4000
# -- "train" loss 0.0002739 -- "valid" loss 0.005559 -- "total" loss 1.306e-05
# Epoch number :  4100
# -- "train" loss 0.0002229 -- "valid" loss 0.005712 -- "total" loss 1.206e-05
# Epoch number :  4200
# -- "train" loss 0.000555 -- "valid" loss 0.00596 -- "total" loss 1.626e-05
# Epoch number :  4300
# -- "train" loss 0.0002314 -- "valid" loss 0.005604 -- "total" loss 1.176e-05
# Epoch number :  4400
# -- "train" loss 0.0002148 -- "valid" loss 0.005339 -- "total" loss 1.198e-05
# 2041.2235140800476

# %% [markdown]
# # 4-Online transfer

# %%
lamda = 0.0
train_weight9 = [0., 0.1, 0., 0., 0.1, 0., 0., 0., 0.,]
valid_weight9 = [0. if (i!=0) else 0.1 for i in train_weight9]
train_alpha = torch.Tensor(train_weight9 + [0.] )
valid_alpha = torch.Tensor(valid_weight9 + [0.])
device = 'cuda'

pretrain_model_path = './model/wx_inner/wx_inner_pretrain_end.pt'
finetune_model_path = './model/wx_inner/wx_inner_finetune'

# %%
device = 'cuda'
trainer = Trainer(lr = 8e-4, n_epochs = None,device = device, patience = 1200,
                  lamda = lamda, alpha = None, model_name=None)

# %%
res_dict = {}

for name in new_test[:]:

    stride = 1
    test_fea, test_lbl = [], []
    tmp_fea, tmp_lbl = all_loader[name]['fea'],all_loader[name]['lbl']
    test_fea.append(tmp_fea[::stride])
    test_lbl.append(tmp_lbl[::stride])
    test_fea = np.vstack(test_fea)
    test_lbl = np.vstack(test_lbl).squeeze()

    batch_size = 20 if len(test_fea)%20!=1 else 21
    rul_true, rul_pred, rul_base, SOH_TRUE, SOH_PRED, SOH_BASE = [], [], [], [], [], []
    for i in range(test_fea.shape[0] // batch_size + 1):

        test_fea_ = test_fea[i*batch_size: i*batch_size+batch_size].transpose(0,3,2,1)
        test_lbl_ = test_lbl[i*batch_size: i*batch_size+batch_size]
        testset = TensorDataset(torch.Tensor(test_fea_), torch.Tensor(test_lbl_))
        test_loader = DataLoader(testset, batch_size=batch_size,)
        if test_fea_.shape[0] == 0: continue

        model = CRNN(100,4,64,64)
        model = model.to(device)
        model.load_state_dict(torch.load(pretrain_model_path))

        _, y_pred, _, _, soh_pred = trainer.test(test_loader, model)
        rul_base.append(y_pred.cpu().detach().numpy())
        SOH_BASE.append(soh_pred.cpu().detach().numpy())

        for p in model.soh.parameters():
            p.requires_grad = False
        for p in model.rul.parameters():
            p.requires_grad = False
        for p in model.cnn.parameters():
            p.requires_grad = False

        tic = time.time()
        seed_torch(2021)

        num_epochs = 120
        model_load = False
        trainer = FineTrainer(lr = 1e-4, n_epochs = num_epochs,device = device, patience = 1000,
                      lamda = lamda, train_alpha = train_alpha, valid_alpha = valid_alpha, model_name=finetune_model_path)
        model ,train_loss, valid_loss, total_loss, added_loss = trainer.train(test_loader, test_loader, model, model_load)

        y_true, y_pred, mse_loss, soh_true, soh_pred = trainer.test(test_loader, model)
        rul_true.append(y_true.cpu().detach().numpy().reshape(-1,1))
        rul_pred.append(y_pred.cpu().detach().numpy())
        SOH_TRUE.append(soh_true.cpu().detach().numpy())
        SOH_PRED.append(soh_pred.cpu().detach().numpy())

    rul_true = np.vstack(rul_true).squeeze()
    rul_pred = np.vstack(rul_pred).squeeze()
    rul_base = np.vstack(rul_base).squeeze()
    SOH_TRUE = np.vstack(SOH_TRUE)
    SOH_PRED = np.vstack(SOH_PRED)
    SOH_BASE = np.vstack(SOH_BASE)

    fig = plt.figure(figsize=(20,10))
    plt.subplot(121)
    plt.plot(rul_true[:]*rul_factor, '.',label='true')
    plt.plot(rul_pred[:]*rul_factor, '.',label='transfer')
    plt.legend(fontsize=20)
    plt.title(f'{name} cycle life ({len(test_fea)}): RUL',fontsize=20)
    plt.xlabel('Cycle',fontsize=20)
    plt.ylabel('RUL',fontsize=20)
    plt.subplot(122)
    for seq_num in range(9,10):
        plt.plot(SOH_TRUE[:,seq_num]*cap_factor, '.',label='true')
        plt.plot(SOH_PRED[:,seq_num]*cap_factor, '.',label='transfer')
    plt.legend(fontsize=20)
    plt.title(f'{name}: Capacity',fontsize=20)
    plt.xlabel('Cycle',fontsize=20)
    plt.ylabel('Capacity',fontsize=20)
    plt.show()
    
    res_dict.update({name:{
        'rul':{
            'true':rul_true[:]*rul_factor,
            'base':rul_base[:]*rul_factor,
            'transfer':rul_pred[:]*rul_factor,
        },
        'soh':{
            'true':SOH_TRUE[:,9]*cap_factor,
            'base':SOH_BASE[:,9]*cap_factor,
            'transfer':SOH_PRED[:,9]*cap_factor,
        },
                          }
                    })
    save_obj(res_dict,'./result/res_dict')

# %% [markdown]
# # 5-Result visualization

# %%
result = load_obj('result/res_dict')

# %%
new_test  = ['9-6','4-5','1-2', '10-7','1-1', '6-1','6-6', '9-4','10-4','8-5', '5-3','10-6',
            '2-5','6-2','3-1','8-8', '8-1','8-6','7-6','6-8','7-5','10-1']

test_1 = ['1-1','7-5','9-4','10-1','10-4','10-7']
channel_1 = ['#1', '#50', '#65', '#70', '#73', '#76']

test_2 = ['1-2', '5-3','6-1','6-6','6-8']
channel_2 = ['#2','#34', '#39', '#44', '#45']

test_3 = ['2-5','4-5','7-6','8-1','8-8','9-6']
channel_3 = ['#12', '#28', '#51', '#54', '#61', '#67']

test_4 = ['3-1','6-2','8-5','8-6','10-6',]
channel_4 = ['#16', '#40', '#58', '#59', '#75']

# %%
fig = plt.figure(figsize=(9,9))
x_lim = 2000
plt.plot(range(x_lim), range(x_lim),'-',c='k', linewidth=3,label='y=x')
cmap = plt.get_cmap('YlGnBu')
norm = plt.Normalize(vmin=0.3, vmax=1)

colors = ['#09C988','b','#FDB137','PURPLE','#40CEE3','red',]

label_names = channel_1[:]
for i, name in enumerate(test_1):
    interval = 20

    rul_true = result[name]['rul']['true'] 
    rul_base = result[name]['rul']['base']
    rul_pred = result[name]['rul']['transfer']
    
    color = [len(rul_true)/2700]*len(rul_true)
    color = color[::interval]

    plt.plot(rul_true[::interval], rul_pred[::interval], '.',markersize=11,label=label_names[i], c=colors[i])
plt.legend(fontsize=25,loc="lower right")
x_major_locator=MultipleLocator(400)
y_major_locator=MultipleLocator(400)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
ax.yaxis.set_major_locator(y_major_locator)
plt.xlim((0,x_lim))
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(length=10)
plt.xticks([0,1000,2000],size=25)
plt.yticks([0,1000,2000],size=25)

plt.ylabel('Predicted RUL (cycles)',fontsize=30,family='Avenir')
plt.xlabel('Actual RUL (cycles)',fontsize=30,family='Avenir')
# plt.savefig(f'Figure/fig3/rul_1.png',dpi=1200,bbox_inches='tight')
# Out:
# Text(0.5, 0, 'Actual RUL (cycles)')

# %%
fig = plt.figure(figsize=(9,3))
cmap = plt.get_cmap('YlGnBu')
norm = plt.Normalize(vmin=0.3, vmax=1)
error_list = []

colors = ['k','mediumpurple','red','chocolate','limegreen','steelblue',]
label_names = ['#1', '#50','#65','#70', '#73', '#76' ]

for i, name in enumerate(test_1):
    interval = 1

    rul_true = result[name]['rul']['true'] 
    rul_pred = result[name]['rul']['transfer']
    tmp = rul_pred[::interval] - rul_true[::interval]
    error_list.append(tmp.reshape(-1,1))
    
error_array = np.vstack(error_list)

fig = plt.figure(figsize=(9,6))
sns.kdeplot(error_array.squeeze(),shade=True,color='k')
plt.xticks([-150, 0, 150],size=50)
plt.yticks([],size=50)
plt.xlim(-151,200)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(length=10)
plt.ylabel('Density',fontsize=50,family='Avenir')
# plt.savefig(f'Figure/fig3/drul_1',dpi=1200,bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Density')

# %%
fig = plt.figure(figsize=(9, 9))
x_lim = 2700
plt.plot(range(x_lim), range(x_lim), '-', c='k', linewidth=3, label='y=x')
cmap = plt.get_cmap('YlGnBu')
norm = plt.Normalize(vmin=0.3, vmax=1)

colors = ['#09C988', 'b', '#FDB137', 'PURPLE', '#40CEE3', 'red']

label_names = channel_2[:]
for i, name in enumerate(test_2):
    interval = 20

    rul_true = result[name]['rul']['true']       ## actual rul
    rul_base = result[name]['rul']['base']       ## predicted rul without model transfer
    rul_pred = result[name]['rul']['transfer']   ## predicted rul with model transfer
    
    color = [len(rul_true) / 2700] * len(rul_true)
    color = color[::interval]
    plt.plot(rul_true[::interval], rul_pred[::interval], '.', markersize=11, label=label_names[i], c=colors[i])
    
plt.legend(fontsize=25, loc="lower right")
x_major_locator = MultipleLocator(400)
y_major_locator = MultipleLocator(400)
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
ax.yaxis.set_major_locator(y_major_locator)
plt.xlim((0, x_lim))
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(length=10)
plt.xticks([0, 1000, 2000], size=25)
plt.yticks([0, 1000, 2000], size=25)

plt.ylabel('Predicted RUL (cycles)', fontsize=30, family='Avenir')
plt.xlabel('Actual RUL (cycles)', fontsize=30, family='Avenir')
# Out:
# Text(0.5, 0, 'Actual RUL (cycles)')

# %%
fig = plt.figure(figsize=(9,3))
cmap = plt.get_cmap('YlGnBu')
norm = plt.Normalize(vmin=0.3, vmax=1)
error_list = []

colors = ['k','mediumpurple','red','chocolate','limegreen','steelblue',]
label_names = ['#1', '#50','#65','#70', '#73', '#76' ]

for i, name in enumerate(test_2):
    interval = 1

    rul_true = result[name]['rul']['true'] 
    rul_pred = result[name]['rul']['transfer']
    tmp = rul_pred[::interval] - rul_true[::interval]
    error_list.append(tmp.reshape(-1,1))
    
error_array = np.vstack(error_list)

fig = plt.figure(figsize=(9,6))
sns.kdeplot(error_array.squeeze(),shade=True,color='k')
plt.xticks([-600, -250, 100],size=50)
plt.yticks([],size=50)
plt.xlim(-650,150)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(length=10)
plt.ylabel('Density',fontsize=50,family='Avenir')
# Out:
# Text(0, 0.5, 'Density')

# %%
fig = plt.figure(figsize=(9,9))
x_lim = 2000
plt.plot(range(x_lim), range(x_lim),'-',c='k', linewidth=3,label='y=x')
cmap = plt.get_cmap('YlGnBu')
norm = plt.Normalize(vmin=0.3, vmax=1)

colors = ['#09C988','b','#FDB137','PURPLE','#40CEE3','red',]

label_names = channel_3[:]
for i, name in enumerate(test_3):
    interval = 20

    rul_true = result[name]['rul']['true'] 
    rul_base = result[name]['rul']['base']
    rul_pred = result[name]['rul']['transfer']
    
    color = [len(rul_true)/2700]*len(rul_true)
    color = color[::interval]

    plt.plot(rul_true[::interval], rul_pred[::interval], '.',markersize=11,label=label_names[i], c=colors[i])
plt.legend(fontsize=25,loc="lower right")
x_major_locator=MultipleLocator(400)
y_major_locator=MultipleLocator(400)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
ax.yaxis.set_major_locator(y_major_locator)
plt.xlim((0,x_lim))
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(length=10)
plt.xticks([0,1000,2000],size=25)
plt.yticks([0,1000,2000],size=25)

plt.ylabel('Predicted RUL (cycles)',fontsize=30,family='Avenir')
plt.xlabel('Actual RUL (cycles)',fontsize=30,family='Avenir')
# Out:
# Text(0.5, 0, 'Actual RUL (cycles)')

# %%
fig = plt.figure(figsize=(9,3))
cmap = plt.get_cmap('YlGnBu')
norm = plt.Normalize(vmin=0.3, vmax=1)
error_list = []

colors = ['k','mediumpurple','red','chocolate','limegreen','steelblue',]
label_names = ['#1', '#50','#65','#70', '#73', '#76' ]

for i, name in enumerate(test_3):
    interval = 1

    rul_true = result[name]['rul']['true'] 
    rul_pred = result[name]['rul']['transfer']
    tmp = rul_pred[::interval] - rul_true[::interval]
    error_list.append(tmp.reshape(-1,1))
    
error_array = np.vstack(error_list)

fig = plt.figure(figsize=(9,6))
sns.kdeplot(error_array.squeeze(),shade=True,color='k')
plt.xticks([-100, 200, 500],size=50)
plt.yticks([],size=50)
plt.xlim(-150,650)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(length=10)
plt.ylabel('Density',fontsize=50,family='Avenir')
# Out:
# Text(0, 0.5, 'Density')

# %%
fig = plt.figure(figsize=(9,9))
x_lim = 2400
plt.plot(range(x_lim), range(x_lim),'-',c='k', linewidth=3,label='y=x')
cmap = plt.get_cmap('YlGnBu')
norm = plt.Normalize(vmin=0.3, vmax=1)

colors = ['#09C988','b','#FDB137','PURPLE','#40CEE3','red',]

label_names = channel_4[:]
for i, name in enumerate(test_4):
    interval = 20

    rul_true = result[name]['rul']['true'] 
    rul_base = result[name]['rul']['base']
    rul_pred = result[name]['rul']['transfer']
    
    color = [len(rul_true)/2700]*len(rul_true)
    color = color[::interval]

    plt.plot(rul_true[::interval], rul_pred[::interval], '.',markersize=11,label=label_names[i], c=colors[i])
plt.legend(fontsize=25,loc="lower right")
x_major_locator=MultipleLocator(400)
y_major_locator=MultipleLocator(400)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
ax.yaxis.set_major_locator(y_major_locator)
plt.xlim((0,x_lim))
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(length=10)
plt.xticks([0,1000,2000],size=25)
plt.yticks([0,1000,2000],size=25)

plt.ylabel('Predicted RUL (cycles)',fontsize=30,family='Avenir')
plt.xlabel('Actual RUL (cycles)',fontsize=30,family='Avenir')
# Out:
# Text(0.5, 0, 'Actual RUL (cycles)')

# %%
fig = plt.figure(figsize=(9,3))
cmap = plt.get_cmap('YlGnBu')
norm = plt.Normalize(vmin=0.3, vmax=1)
error_list = []

colors = ['k','mediumpurple','red','chocolate','limegreen','steelblue',]
label_names = ['#1', '#50','#65','#70', '#73', '#76' ]

for i, name in enumerate(test_4):
    interval = 1

    rul_true = result[name]['rul']['true'] 
    rul_pred = result[name]['rul']['transfer']
    tmp = rul_pred[::interval] - rul_true[::interval]
    error_list.append(tmp.reshape(-1,1))
    
error_array = np.vstack(error_list)

fig = plt.figure(figsize=(9,6))
sns.kdeplot(error_array.squeeze(),shade=True,color='k')
plt.xticks([-200, 0, 200],size=50)
plt.yticks([],size=50)
plt.xlim(-200,300)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(length=10)
plt.ylabel('Density',fontsize=50,family='Avenir')
# Out:
# Text(0, 0.5, 'Density')

# %%
fig = plt.figure(figsize=(9,9))
cmap = plt.get_cmap('YlGnBu')
x_lim = 2000
norm = plt.Normalize(vmin=0.3, vmax=1)
colors = ['#09C988','b','#FDB137','PURPLE','#40CEE3','red',]

label_names = channel_1[:]
for i, name in enumerate(test_1):
    interval = 20
    
    A = load_obj(f'./data/our_data/{name}')[name]
    end = A['rul'][1]  
    A_rul = A['rul']
    A_life = A['rul'][1]


    rul_true = result[name]['soh']['true'] 
    rul_base = result[name]['soh']['base']
    rul_pred = result[name]['soh']['transfer']
    start = end - len(rul_true)
    
    color = [len(rul_true)/2700]*len(rul_true)
    color = color[::interval]

    plt.plot(range(start, end, interval), rul_true[::interval]/1000, '-',markersize=11, c=colors[i])
    plt.plot(range(start, end, interval), rul_pred[::interval]/1000, '.',markersize=11,label=label_names[i], c=colors[i])
plt.legend(fontsize=25,loc="lower left")
x_major_locator=MultipleLocator(400)
y_major_locator=MultipleLocator(0.05)
plt.xticks(range(0,x_lim+1,400),size=30)
plt.yticks(size=30)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(length=10)
plt.xticks([0,1000,2000],size=25)
plt.yticks([0.9,1.0,1.1, 1.2],size=25)
plt.ylabel('Estimated capacity (Ah)',fontsize=30,family='Avenir')
plt.xlabel('Cycle number',fontsize=30,family='Avenir')
# Out:
# Text(0.5, 0, 'Cycle number')

# %%
fig = plt.figure(figsize=(9,9))
cmap = plt.get_cmap('YlGnBu')
norm = plt.Normalize(vmin=0.3, vmax=1)
error_list = []

colors = ['orange','mediumpurple','red','chocolate','limegreen','steelblue',]

for i, name in enumerate(test_1):
    interval = 1
    rul_true = result[name]['soh']['true'] 
    rul_base = result[name]['soh']['base']
    rul_pred = result[name]['soh']['transfer']
    tmp = (rul_true[::interval] - rul_pred[::interval])/1000
    error_list.append(tmp.reshape(-1,1))
error_array = np.vstack(error_list)

fig = plt.figure(figsize=(9,6))
sns.kdeplot(error_array.squeeze()*1000,shade=True,color='k')
plt.xticks([-8, -2, 4],size=50)
plt.yticks([],size=50)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(length=10)
plt.ylabel('Density',fontsize=50,family='Avenir')
plt.xlim(-8.1, 4.5)
# Out:
# (-8.1, 4.5)

# %%
fig = plt.figure(figsize=(9, 9))
cmap = plt.get_cmap('YlGnBu')
x_lim = 2700
norm = plt.Normalize(vmin=0.3, vmax=1)
colors = ['#09C988', 'b', '#FDB137', 'PURPLE', '#40CEE3', 'red']

label_names = channel_2[:]
for i, name in enumerate(test_2):
    interval = 20
    
    A = load_obj(f'./data/our_data/{name}')[name]
    end = A['rul'][1]  
    A_rul = A['rul']
    A_life = A['rul'][1]


    rul_true = result[name]['soh']['true']        ## actual capacity
    rul_base = result[name]['soh']['base']        ## estimated capacity without model transfer
    rul_pred = result[name]['soh']['transfer']    ## estimated capacity with model transfer
    start = end - len(rul_true)
    
    color = [len(rul_true) / 2700] * len(rul_true)
    color = color[::interval]
    plt.plot(range(start, end, interval), rul_true[::interval]/1000, '-', markersize=11, c=colors[i])
    plt.plot(range(start, end, interval), rul_pred[::interval]/1000, '.', markersize=11, label=label_names[i], 
             c=colors[i])
    
plt.legend(fontsize=25, loc="lower left")
x_major_locator = MultipleLocator(400)
y_major_locator = MultipleLocator(0.05)
plt.xticks(range(0, x_lim+1, 400), size=30)
plt.yticks(size=30)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(length=10)
plt.xticks([0, 1000, 2000], size=25)
plt.yticks([0.9, 1.0, 1.1, 1.2], size=25)
plt.ylabel('Estimated capacity (Ah)', fontsize=30, family='Avenir')
plt.xlabel('Cycle number', fontsize=30, family='Avenir')
# Out:
# Text(0.5, 0, 'Cycle number')

# %%
fig = plt.figure(figsize=(9,9))
cmap = plt.get_cmap('YlGnBu')
norm = plt.Normalize(vmin=0.3, vmax=1)
error_list = []

colors = ['orange','mediumpurple','red','chocolate','limegreen','steelblue',]

for i, name in enumerate(test_2):
    interval = 1
    rul_true = result[name]['soh']['true'] 
    rul_base = result[name]['soh']['base']
    rul_pred = result[name]['soh']['transfer']
    tmp = (rul_true[::interval] - rul_pred[::interval])/1000
    error_list.append(tmp.reshape(-1,1))
error_array = np.vstack(error_list)

fig = plt.figure(figsize=(9,6))
sns.kdeplot(error_array.squeeze()*1000,shade=True,color='k')
plt.xticks([-8, 0, 8],size=50)
plt.yticks([],size=50)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(length=10)
plt.ylabel('Density',fontsize=50,family='Avenir')
plt.xlim(-10, 10)
# Out:
# (-10.0, 10.0)

# %%
fig = plt.figure(figsize=(9,9))
cmap = plt.get_cmap('YlGnBu')
x_lim = 1800
norm = plt.Normalize(vmin=0.3, vmax=1)
colors = ['#09C988','b','#FDB137','PURPLE','#40CEE3','red',]

label_names = channel_3[:]
for i, name in enumerate(test_3):
    interval = 20
    
    A = load_obj(f'./data/our_data/{name}')[name]
    end = A['rul'][1]  
    A_rul = A['rul']
    A_life = A['rul'][1]


    rul_true = result[name]['soh']['true'] 
    rul_base = result[name]['soh']['base']
    rul_pred = result[name]['soh']['transfer']
    start = end - len(rul_true)
    
    color = [len(rul_true)/2700]*len(rul_true)
    color = color[::interval]

    plt.plot(range(start, end, interval), rul_true[::interval]/1000, '-',markersize=11, c=colors[i])
    plt.plot(range(start, end, interval), rul_pred[::interval]/1000, '.',markersize=11,label=label_names[i], c=colors[i])
plt.legend(fontsize=25,loc="lower left")
x_major_locator=MultipleLocator(400)
y_major_locator=MultipleLocator(0.05)
plt.xticks(range(0,x_lim+1,400),size=30)
plt.yticks(size=30)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(length=10)
plt.xticks([0,1000,2000],size=25)
plt.yticks([0.9,1.0,1.1, 1.2],size=25)
plt.ylabel('Estimated capacity (Ah)',fontsize=30,family='Avenir')
plt.xlabel('Cycle number',fontsize=30,family='Avenir')
# Out:
# Text(0.5, 0, 'Cycle number')

# %%
fig = plt.figure(figsize=(9,9))
cmap = plt.get_cmap('YlGnBu')
norm = plt.Normalize(vmin=0.3, vmax=1)
error_list = []

colors = ['orange','mediumpurple','red','chocolate','limegreen','steelblue',]

for i, name in enumerate(test_3):
    interval = 1
    rul_true = result[name]['soh']['true'] 
    rul_base = result[name]['soh']['base']
    rul_pred = result[name]['soh']['transfer']
    tmp = (rul_true[::interval] - rul_pred[::interval])/1000
    error_list.append(tmp.reshape(-1,1))
error_array = np.vstack(error_list)

fig = plt.figure(figsize=(9,6))
sns.kdeplot(error_array.squeeze()*1000,shade=True,color='k')
plt.xticks([-6, 0, 6],size=50)
plt.yticks([],size=50)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(length=10)
plt.ylabel('Density',fontsize=50,family='Avenir')
plt.xlim(-8, 8)
# Out:
# (-8.0, 8.0)

# %%
fig = plt.figure(figsize=(9,9))
cmap = plt.get_cmap('YlGnBu')
x_lim = 2400
norm = plt.Normalize(vmin=0.3, vmax=1)
colors = ['#09C988','b','#FDB137','PURPLE','#40CEE3','red',]

label_names = channel_4[:]
for i, name in enumerate(test_4):
    interval = 20
    
    A = load_obj(f'./data/our_data/{name}')[name]
    end = A['rul'][1]  
    A_rul = A['rul']
    A_life = A['rul'][1]


    rul_true = result[name]['soh']['true'] 
    rul_base = result[name]['soh']['base']
    rul_pred = result[name]['soh']['transfer']
    start = end - len(rul_true)
    
    color = [len(rul_true)/2700]*len(rul_true)
    color = color[::interval]

    plt.plot(range(start, end, interval), rul_true[::interval]/1000, '-',markersize=11, c=colors[i])
    plt.plot(range(start, end, interval), rul_pred[::interval]/1000, '.',markersize=11,label=label_names[i], c=colors[i])
plt.legend(fontsize=25,loc="lower left")
x_major_locator=MultipleLocator(400)
y_major_locator=MultipleLocator(0.05)
plt.xticks(range(0,x_lim+1,400),size=30)
plt.yticks(size=30)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(length=10)
plt.xticks([0,1000,2000],size=25)
plt.yticks([0.9,1.0,1.1, 1.2],size=25)
plt.ylabel('Estimated capacity (Ah)',fontsize=30,family='Avenir')
plt.xlabel('Cycle number',fontsize=30,family='Avenir')
# Out:
# Text(0.5, 0, 'Cycle number')

# %%
fig = plt.figure(figsize=(9,9))
cmap = plt.get_cmap('YlGnBu')
norm = plt.Normalize(vmin=0.3, vmax=1)
error_list = []

colors = ['orange','mediumpurple','red','chocolate','limegreen','steelblue',]

for i, name in enumerate(test_4):
    interval = 1
    rul_true = result[name]['soh']['true'] 
    rul_base = result[name]['soh']['base']
    rul_pred = result[name]['soh']['transfer']
    tmp = (rul_true[::interval] - rul_pred[::interval])/1000
    error_list.append(tmp.reshape(-1,1))
error_array = np.vstack(error_list)

fig = plt.figure(figsize=(9,6))
sns.kdeplot(error_array.squeeze()*1000,shade=True,color='k')
plt.xticks([-8, 0, 8],size=50)
plt.yticks([],size=50)
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.tick_params(length=10)
plt.ylabel('Density',fontsize=50,family='Avenir')
plt.xlim(-9, 9)
# Out:
# (-9.0, 9.0)

# %%
new_test = test_1 + test_2 + test_3 + test_4
test_channel = channel_1 + channel_2 + channel_3 + channel_4
test_nm_ch = set(zip(test_channel,new_test))

sort_new_test = sorted(test_nm_ch, key = lambda x: int(x[0][1:]))
test_name = [i[0] for i in sort_new_test]
test_channel = [i[1] for i in sort_new_test]
cols = ['rmse_before','rmse_after',
       'r2_before','r2_after',
       'mae_before','mae_after',]

table_wx = pd.DataFrame(index=[test_name,test_channel],columns=cols)
table_wx.loc['All',:] = 0

# %%
stride = 1
rmse_before_list, r2_before_list, mae_before_list = [], [], []
rmse_after_list, r2_after_list, mae_after_list = [], [], []


for (code, name) in sort_new_test[:]:
    A = load_obj(f'./data/our_data/{name}')[name]
    end = A['rul'][1]
    
    A_rul = A['rul']
    A_life = A['rul'][1]
    rul_true = result[name]['rul']['true']
    rul_base = result[name]['rul']['base']
    rul_pred = result[name]['rul']['transfer']
    start = end - len(rul_true)
#     print(name, A_life, rul_true[0])
    
    rmse_before = np.sqrt(mean_squared_error(rul_true,rul_base))
    rmse_after = np.sqrt(mean_squared_error(rul_true,rul_pred))
#     print('rmse:','%.3g'%rmse_before,'%.3g'%rmse_after)
    table_wx.loc[(code, name),['rmse_before','rmse_after']] = ['%.3g'%rmse_before, '%.3g'%rmse_after]
    
    r2_before = r2_score(rul_true,rul_base)
    r2_after = r2_score(rul_true,rul_pred)
#     print('r2:','%.3g'%r2_before, '%.3g'%r2_after)
    table_wx.loc[(code, name),['r2_before','r2_after']] = ['%.3g'%r2_before, '%.3g'%r2_after]
    
    mae_before = mean_absolute_error(rul_true,rul_base) / A_life * 100
    mae_after = mean_absolute_error(rul_true, rul_pred) / A_life * 100
#     print('mae/life:','%.3g'%mae_before, '%.3g'%mae_after)
    table_wx.loc[(code, name),['mae_before','mae_after']] = ['%.3g'%mae_before, '%.3g'%mae_after]
    
#     print('')
    
    rmse_before_list.append(rmse_before)
    rmse_after_list.append(rmse_after)
    
    r2_before_list.append(r2_before)
    r2_after_list.append(r2_after)
    
    mae_before_list.append(mae_before)
    mae_after_list.append(mae_after)

table_wx.loc['All',['rmse_before','rmse_after']] = [
                                                                 '%.3g'%np.mean(rmse_before_list), 
                                                                 '%.3g'%np.mean(rmse_after_list)]
table_wx.loc['All',['r2_before','r2_after']] = [
                                                           '%.3g'%np.mean(r2_before_list), 
                                                           '%.3g'%np.mean(r2_after_list)]   
table_wx.loc['All',['mae_before','mae_after']] = [
                                                              '%.3g'%np.mean(mae_before_list), 
                                                              '%.3g'%np.mean(mae_after_list)]

# %%
table_wx
# Out:
#          rmse_before rmse_after r2_before r2_after mae_before mae_after
# #1  1-1           50       42.4     0.986     0.99       2.34         2
# #2  1-2          253        273     0.889    0.872       8.23      8.54
# #12 2-5          386        358    0.0147    0.154       23.5      21.8
# #16 3-1         93.5        133     0.971    0.941       4.02      5.97
# #28 4-5          325        321     0.452    0.468       16.7      17.3
# #34 5-3          278        308     0.868    0.838       8.65      9.63
# #39 6-1          131        110     0.917    0.941       7.15      5.75
# #40 6-2         94.3        132     0.969     0.94       3.97      5.67
# #44 6-6          386        348     0.698    0.754       14.2      12.7
# #45 6-8          330        360     0.775    0.733       12.3      13.6
# #50 7-5         63.9       49.2     0.985    0.991       2.87      2.09
# #51 7-6          217        196     0.703    0.757       11.4      11.4
# #54 8-1          186        214     0.742    0.659       12.2      14.5
# #58 8-5         46.5       76.4     0.985    0.959       2.81      4.27
# #59 8-6         93.4         70     0.981    0.989       3.63      2.65
# #61 8-8          370        383     0.388    0.347       18.6      19.4
# #65 9-4         99.8       67.1     0.968    0.986       4.35      2.72
# #67 9-6          297        287     0.635    0.658       15.4      14.8
# #70 10-1        80.3       57.6     0.972    0.986       3.31      2.64
# #73 10-4          69       60.5     0.982    0.986       3.24       2.9
# #75 10-6         121       94.9     0.965    0.979       4.42      3.25
# #76 10-7        85.6       51.1     0.971     0.99       3.27      1.86
# All              184        181      0.81    0.814       8.48      8.43
